.00836436855849967,0.7984861144127182,0.22774986140927292,1.0393226393612731,-1.8723473482821371,2.200583735883698,-0.7449565181389847,0.13513828726351712,-0.1727486761135798],"y":[0.1048757836352462,-0.08108365513388299,0.604911114142477,0.3587938601638652,-1.2135287766613534,0.26971524548800935,0.4002035655127256,-0.43182327523575803,0.8952188374543482,-0.08115906424404212,0.22030176490189413,-1.3610861570572845,1.7969845231500117,-0.3385264212264844,0.044260029984002566,-0.8183571497289426,0.38243097640798945,0.24642542621169963,-2.1512711779911835,0.6513677871676182,-0.5459398222942253,-0.341048713554321,0.28248942367624336,0.48298160001374163,1.1591622273139397,-0.24906420447815875,-0.13311449791834548,-0.7482095192823396,-0.13697876938393355,-0.051673711948932353,1.1073794137047166,-0.14327566662106883,1.2727063894692932,0.5291846526106512,1.2586603098989906,-0.9174073939766524,1.1542877166813876,0.22979083304428652,0.6181291651089315,1.3629143768527663,0.05903297522379652,-0.4232219704487467,0.6880811434034129,-0.656876964764699,2.0252556010207985,-1.587373994493509,-0.7985450200513303,-0.17883928620737471,0.24607059129169548,0.25244817705449674,-0.6040506589474247,0.8357992141543139,-0.997834281999179,0.29945146658453237,-0.6526596250437244,0.8257283612687518,0.301306634056431,0.6798904791828876,0.0974960840241832,0.7366679463963148,0.11881727507507295,1.609357729799459,-0.5145445416180311,0.4560468702 ...

# %%
print(lr.coef_)
# Out:
# [94.15340046 25.14020544]

# %%
print(lr.intercept_)
# Out:
# -1.2948070414553925

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# Using Sklearn's Linear Regression

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
print(reg.coef_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]

# %%
print(reg.intercept_)
# Out:
# 151.88331005254167

# %% [markdown]
# Making our own Linear Regression Class

# %%
class MyLR:

    def __init__(self):
        self.coeff_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1) 

        # calculate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]

    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
lr = MyLR()

# %%
lr.fit(X_train,y_train)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43993386615689756

# %%
print(lr.coef_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]

# %%
print(lr.intercept_)
# Out:
# 151.8833100525417
